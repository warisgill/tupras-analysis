# %%
import pandas as pd
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
import matplotlib

# %%
df = pd.read_excel("/home/kutem/github/tupras-analysis/tupras-valve.xlsx",  usecols = "A,B,C,D")
# print(df.head())
mv = df["MV"].values
pv = df["PV"].values
l = 27
mvf = signal.wiener(mv[0:l])
pvf = signal.wiener(pv[0:l])

time_stamp = df["Time"].values
time_stamp = matplotlib.dates.date2num(time_stamp)
print(mv, pv, time_stamp)
# Out:
# [78.2889    78.3021851 78.32133   ... 75.05712   75.05358   75.05112  ] [23.4913311 23.50538   23.5105572 ... 23.49334   23.497654  23.50571  ] [737394.05071759 737394.0508912  737394.05106481 ... 737402.47884259
#  737402.4790162  737402.47918981]

# %%
plt.scatter(mv[43387:l],pv[0:l], s=2)
plt.plot(mv[43387:l],pv[0:l])
plt.show()

# %%
plt.scatter(mv[0:l],pvf[0:l], s=2)
plt.plot(mvf[0:l],pvf[0:l])
plt.show()

# %%
plt.scatter(pv[0:l],mv[0:l], s=2)
plt.plot(pv[0:l], mv[0:l])
plt.show()
