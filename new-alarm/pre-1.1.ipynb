# %% [markdown]
# ### Summary
# Concatination of raw csv files into 1 file

# %%
import numpy as np
import json
import pandas as pd
from datetime import datetime
from dateutil.parser import parse

# %%
f0 = "formatted-pre-1-result.csv"
f1 = "formatted-pre-1-nisan2019.csv"
f2 = "formatted-pre-1-mayis2019.csv" 
f3 = "formatted-pre-1-haziran2019.csv"

output_f = 'formatted-pre-1-months4.csv' 

path = "./data/new/"
df0 = pd.read_csv(path + f0, parse_dates = ["EventTime"])
df1 = pd.read_csv(path + f1, parse_dates = ["EventTime"])
df2 = pd.read_csv(path + f2, parse_dates = ["EventTime"])
df3 = pd.read_csv(path + f3, parse_dates = ["EventTime"])

# %%
df0.tail(2)
# Out:
#        MachineName            ServerProgID ServerNodeName  \
# 606530      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 606531      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
#
#               SubscriptionName SourceName           EventTime  EventTime_MS  \
# 606530  Yokogawa.ExaopcAECS1.1   47TI931A 2019-03-21 03:35:43      70539648
# 606531  Yokogawa.ExaopcAECS1.1    48AI004 2019-03-21 03:35:30     -59460352
#
#         Severity                                           Message  Quality  \
# 606530       500  47TI931A C5 1.YTK GIRDISCAP SICAK PV = 691 C IOP        0
# 606531       500              48AI004 48S-1 H2S PV = 0.00 %H2S IOP        0
#
#         ... AckReq                     ActiveTime  ActiveTime_MS    Cookie  \
# 606530  ...   True  2019/03/21 03:35:43.000000000       70539648  10591992
# 606531  ...   True  2019/03/21 03:35:30.000000000      -59460352  10591992
#
#        ActorID                                         Attributes     Area  \
# ...

# %%
df1.tail(2)
# Out:
#         MachineName            ServerProgID ServerNodeName  \
# 1277116      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 1277117      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
#
#                SubscriptionName SourceName           EventTime  EventTime_MS  \
# 1277116  Yokogawa.ExaopcAECS1.1   47TI931A 2019-04-08 07:31:44    -129959936
# 1277117  Yokogawa.ExaopcAECS1.1   47TI931A 2019-04-08 07:32:09     120040064
#
#          Severity                                           Message  Quality  \
# 1277116       500  47TI931A C5 1.YTK GIRDISCAP SICAK PV = 691 C IOP        0
# 1277117       500  47TI931A C5 1.YTK GIRDISCAP SICAK PV = 691 C IOP        0
#
#          ... AckReq                     ActiveTime  ActiveTime_MS    Cookie  \
# 1277116  ...   True  2019/04/08 07:31:44.000000000     -129959936  10591992
# 1277117  ...   True  2019/04/08 07:32:09.000000000      120040064  10591992
#
#         ActorID                                         Attributes     Area  \
# ...

# %%
df2.tail(2)
# Out:
#         ï»¿MachineName            ServerProgID ServerNodeName  \
# 1776437         PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 1776438         PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
#
#                SubscriptionName SourceName           EventTime  EventTime_MS  \
# 1776437  Yokogawa.ExaopcAECS1.1  48TIC2026 2019-05-30 23:57:02     986637056
# 1776438  Yokogawa.ExaopcAECS1.1  48TIC2026 2019-05-30 23:57:31    1276637056
#
#          Severity                                            Message  Quality  \
# 1776437       500  48TIC2026 E208 CKS TEMIZ MDEA PV = -5.2 C VEL+...      192
# 1776438       500  48TIC2026 E208 CKS TEMIZ MDEA PV = -4.9 C VEL-...      192
#
#          ... AckReq               ActiveTime  ActiveTime_MS   Cookie ActorID  \
# 1776437  ...   True  2019-05-30 23:57:01.000      976637056  4497144     NaN
# 1776438  ...   True  2019-05-30 23:57:29.000     1256637056  4497144     NaN
#
# ...

# %%
df3.tail(2)
# Out:
#         MachineName            ServerProgID ServerNodeName  \
# 1845689      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 1845690      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
#
#                SubscriptionName SourceName           EventTime  EventTime_MS  \
# 1845689  Yokogawa.ExaopcAECS1.1  48TIC2026 2019-06-20 22:59:21   -1500450176
# 1845690  Yokogawa.ExaopcAECS1.1  48TIC2026 2019-06-20 22:58:50   -1810450176
#
#          Severity                                         Message  Quality  \
# 1845689       500  48TIC2026 E208 CKS TEMIZ MDEA PV = -5.0 C VEL+      192
# 1845690       500  48TIC2026 E208 CKS TEMIZ MDEA PV = -5.1 C VEL+      192
#
#          ... AckReq                     ActiveTime  ActiveTime_MS   Cookie  \
# 1845689  ...   True  2019/06/20 22:59:21.000000000    -1500450176  4497144
# 1845690  ...   True  2019/06/20 22:58:50.000000000    -1810450176  4497144
#
#         ActorID                                         Attributes     Area  \
# ...

# %%
df = pd.concat([df0,df1, df2, df3], ignore_index=True)
df.to_csv( path + output_f, index=False)
df
# Out:
#         MachineName            ServerProgID ServerNodeName  \
# 0            PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 1            PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 2            PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 3            PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 4            PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# ...             ...                     ...            ...
# 5505775      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 5505776      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 5505777      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 5505778      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
# 5505779      PHD47B  Yokogawa.ExaopcAECS1.1        STN0830
#
#                SubscriptionName SourceName           EventTime  EventTime_MS  \
# 0        Yokogawa.ExaopcAECS1.1  48FIX2040 2019-03-11 05:09:04    1720164352
# 1        Yokogawa.ExaopcAECS1.1   47TI931A 2019-03-11 05:09:24    1920164352
# ...

# %%
cols = ["MachineName","SourceName","EventTime", "Message","Quality","Condition","Mask","NewState","Status"]
df = pd.read_csv(path + output_f, usecols=cols ,parse_dates = ["EventTime"], low_memory=False)
df.to_csv( path + output_f, index=False)
df
# Out:
#         MachineName SourceName           EventTime  \
# 0            PHD47B  48FIX2040 2019-03-11 05:09:04
# 1            PHD47B   47TI931A 2019-03-11 05:09:24
# 2            PHD47B  48TIC2027 2019-03-11 05:09:36
# 3            PHD47B   47TI931A 2019-03-11 05:08:54
# 4            PHD47B   47TI931A 2019-03-11 05:08:36
# ...             ...        ...                 ...
# 5505775      PHD47B   47TI931A 2019-06-20 22:55:55
# 5505776      PHD47B  48TIC2026 2019-06-20 22:58:52
# 5505777      PHD47B  48TIC2026 2019-06-20 22:58:57
# 5505778      PHD47B  48TIC2026 2019-06-20 22:59:21
# 5505779      PHD47B  48TIC2026 2019-06-20 22:58:50
#
#                                                    Message  Quality Condition  \
# 0        48FIX2040 C206'DAN C4'E A.GAZ CPV = -1 m3/h IO...      192      IOP-
# 1        47TI931A C5 1.YTK GIRDISCAP SICAK PV = 691 C I...      192       IOP
# 2        48TIC2027 E209 CIKIS REJEN DRAM PV = -6.0 C IO...      192      IOP-
# ...
